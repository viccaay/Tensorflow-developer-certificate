# %% [markdown]
# # Week 2: Predicting time series
#
# Welcome! In the previous assignment you got some exposure to working with time series data, but you didn't use machine learning techniques for your forecasts. This week you will be using a deep neural network to create forecasts to see how this technique compares with the ones you already tried out. Once again all of the data is going to be generated.
#
# Let's get started!

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %% [markdown]
# ## Generating the data
#
#
# The next cell includes a bunch of helper functions to generate and plot the time series:

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.1,
                    np.cos(season_time * 6 * np.pi), 
                    2 / np.exp(9 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

# %% [markdown]
# You will be generating time series data that greatly resembles the one from last week but with some differences.
#
# **Notice that this time all the generation is done within a function and global variables are saved within a dataclass. This is done to avoid using global scope as it was done in during the previous week.**
#
# If you haven't used dataclasses before, they are just Python classes that provide a convenient syntax for storing data. You can read more about them in the [docs](https://docs.python.org/3/library/dataclasses.html).

# %%
def generate_time_series():
    # The time dimension or the x-coordinate of the time series
    time = np.arange(4 * 365 + 1, dtype="float32")

    # Initial series is just a straight line with a y-intercept
    y_intercept = 10
    slope = 0.005
    series = trend(time, slope) + y_intercept

    # Adding seasonality
    amplitude = 50
    series += seasonality(time, period=365, amplitude=amplitude)

    # Adding some noise
    noise_level = 3
    series += noise(time, noise_level, seed=51)
    
    return time, series


# Save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TIME, SERIES = generate_time_series()
    SPLIT_TIME = 1100
    WINDOW_SIZE = 20
    BATCH_SIZE = 32
    SHUFFLE_BUFFER_SIZE = 1000
    

# Plot the generated series
plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()

# %% [markdown]
# ## Splitting the data
#
# Since you already coded the `train_val_split` function during last week's assignment, this time it is provided for you:

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %% [markdown]
# ## Processing the data
#
# As you saw on the lectures you can feed the data for training by creating a dataset with the appropiate processing steps such as `windowing`, `flattening`, `batching` and `shuffling`. To do so complete the `windowed_dataset` function below.
#
# Notice that this function receives a `series`, `window_size`, `batch_size` and `shuffle_buffer` and the last three of these default to the "global" values defined earlier.
#
# Be sure to check out the [docs](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) about `TF Datasets` if you need any help.

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    
    ### START CODE HERE
    
    # Create dataset from the series
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Slice the dataset into the appropriate windows
    dataset = dataset.window(window_size+1,shift=1,drop_remainder=True)
    
    # Flatten the dataset
    dataset = dataset.flat_map(lambda window:window.batch(window_size + 1))
    
    # Shuffle it
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Split it into the features and labels
    dataset = dataset.map(lambda window: (window[:-1],window[-1]))
    
    # Batch it
    dataset = dataset.batch(batch_size).prefetch(1)
    
    ### END CODE HERE
    
    return dataset

# %% [markdown]
# To test your function you will be using a `window_size` of 1 which means that you will use each value to predict the next one. This for 5 elements since a `batch_size` of 5 is used and no shuffle since `shuffle_buffer` is set to 1.
#
# Given this, the batch of features should be identical to the first 5 elements of the `series_train` and the batch of labels should be equal to elements 2 through 6 of the `series_train`.

# %%
# Test your function with windows size of 1 and no shuffling
test_dataset = windowed_dataset(series_train, window_size=1, batch_size=5, shuffle_buffer=1)

# Get the first batch of the test dataset
batch_of_features, batch_of_labels = next((iter(test_dataset)))

print(f"batch_of_features has type: {type(batch_of_features)}\n")
print(f"batch_of_labels has type: {type(batch_of_labels)}\n")
print(f"batch_of_features has shape: {batch_of_features.shape}\n")
print(f"batch_of_labels has shape: {batch_of_labels.shape}\n")
print(f"batch_of_features is equal to first five elements in the series: {np.allclose(batch_of_features.numpy().flatten(), series_train[:5])}\n")
print(f"batch_of_labels is equal to first five labels: {np.allclose(batch_of_labels.numpy(), series_train[1:6])}")
# Out:
# batch_of_features has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_labels has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_features has shape: (5, 1)
#
# batch_of_labels has shape: (5,)
#
# batch_of_features is equal to first five elements in the series: True
#
# batch_of_labels is equal to first five labels: True

# %% [markdown]
# **Expected Output:**
#
# ```
# batch_of_features has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_labels has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_features has shape: (5, 1)
#
# batch_of_labels has shape: (5,)
#
# batch_of_features is equal to first five elements in the series: True
#
# batch_of_labels is equal to first five labels: True
# ```

# %% [markdown]
# ## Defining the model architecture
#
# Now that you have a function that will process the data before it is fed into your neural network for training, it is time to define you layer architecture.
#
# Complete the `create_model` function below. Notice that this function receives the `window_size` since this will be an important parameter for the first layer of your network.
#
# Hint:
# - You will only need `Dense` layers.
# - The training should be really quick so if you notice that each epoch is taking more than a few seconds, consider trying a different architecture.

# %%
def create_model(window_size=G.WINDOW_SIZE):

    ### START CODE HERE

    model = tf.keras.models.Sequential([ 
        tf.keras.layers.Dense(10, input_shape=[window_size], activation="relu"), 
        tf.keras.layers.Dense(10, activation="relu"), 
        tf.keras.layers.Dense(1)
    ]) 

    model.compile(loss='mse',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9))
    
    ### END CODE HERE

    return model

# %%
# Apply the processing to the whole training series
dataset = windowed_dataset(series_train)

# Save an instance of the model
model = create_model()

# Train it
model.fit(dataset, epochs=1000)
# Out:
# Epoch 1/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 343.4468
# Epoch 2/1000
# 34/34 [==============================] - 0s 888us/step - loss: 272.3680
# Epoch 3/1000
# 34/34 [==============================] - 0s 851us/step - loss: 204.2507
# Epoch 4/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 152.8268
# Epoch 5/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 119.3905
# Epoch 6/1000
# 34/34 [==============================] - 0s 786us/step - loss: 99.5672
# Epoch 7/1000
# 34/34 [==============================] - 0s 871us/step - loss: 88.3986
# Epoch 8/1000
# 34/34 [==============================] - 0s 788us/step - loss: 82.2552
# Epoch 9/1000
# 34/34 [==============================] - 0s 977us/step - loss: 78.7973
# Epoch 10/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 76.5244
# Epoch 11/1000
# 34/34 [==============================] - 0s 827us/step - loss: 75.0363
# Epoch 12/1000
# 34/34 [==============================] - 0s 762us/step - loss: 73.7338
# Epoch 13/1000
# 34/34 [==============================] - 0s 820us/step - loss: 72.6555
# Epoch 14/1000
# 34/34 [==============================] - 0s 954us/step - loss: 71.6781
# Epoch 15/1000
# 34/34 [==============================] - 0s 896us/step - loss: 70.7609
# Epoch 16/1000
# 34/34 [==============================] - 0s 884us/step - loss: 69.9060
# Epoch 17/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 69.0869
# Epoch 18/1000
# 34/34 [==============================] - 0s 855us/step - loss: 68.3163
# Epoch 19/1000
# 34/34 [==============================] - 0s 815us/step - loss: 67.6241
# Epoch 20/1000
# 34/34 [==============================] - 0s 784us/step - loss: 66.8855
# Epoch 21/1000
# 34/34 [==============================] - 0s 799us/step - loss: 66.2587
# Epoch 22/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 65.5789
# Epoch 23/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 64.9661
# Epoch 24/1000
# 34/34 [==============================] - 0s 817us/step - loss: 64.3898
# Epoch 25/1000
# 34/34 [==============================] - 0s 810us/step - loss: 63.8510
# Epoch 26/1000
# 34/34 [==============================] - 0s 796us/step - loss: 63.3261
# Epoch 27/1000
# 34/34 [==============================] - 0s 772us/step - loss: 62.8435
# Epoch 28/1000
# 34/34 [==============================] - 0s 764us/step - loss: 62.3383
# Epoch 29/1000
# 34/34 [==============================] - 0s 969us/step - loss: 61.8891
# Epoch 30/1000
# 34/34 [==============================] - 0s 953us/step - loss: 61.4550
# Epoch 31/1000
# 34/34 [==============================] - 0s 846us/step - loss: 61.0357
# Epoch 32/1000
# 34/34 [==============================] - 0s 966us/step - loss: 60.6352
# Epoch 33/1000
# 34/34 [==============================] - 0s 799us/step - loss: 60.2485
# Epoch 34/1000
# 34/34 [==============================] - 0s 801us/step - loss: 59.9025
# Epoch 35/1000
# 34/34 [==============================] - 0s 792us/step - loss: 59.5321
# Epoch 36/1000
# 34/34 [==============================] - 0s 771us/step - loss: 59.1804
# Epoch 37/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 58.8136
# Epoch 38/1000
# 34/34 [==============================] - 0s 862us/step - loss: 58.5220
# Epoch 39/1000
# 34/34 [==============================] - 0s 914us/step - loss: 58.1899
# Epoch 40/1000
# 34/34 [==============================] - 0s 781us/step - loss: 57.8579
# Epoch 41/1000
# 34/34 [==============================] - 0s 800us/step - loss: 57.5365
# Epoch 42/1000
# 34/34 [==============================] - 0s 833us/step - loss: 57.2459
# Epoch 43/1000
# 34/34 [==============================] - 0s 832us/step - loss: 56.9708
# Epoch 44/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 56.6818
# Epoch 45/1000
# 34/34 [==============================] - 0s 868us/step - loss: 56.4130
# Epoch 46/1000
# 34/34 [==============================] - 0s 981us/step - loss: 56.1631
# Epoch 47/1000
# 34/34 [==============================] - 0s 902us/step - loss: 55.9545
# Epoch 48/1000
# 34/34 [==============================] - 0s 816us/step - loss: 55.6622
# Epoch 49/1000
# 34/34 [==============================] - 0s 808us/step - loss: 55.4238
# Epoch 50/1000
# 34/34 [==============================] - 0s 781us/step - loss: 55.1916
# Epoch 51/1000
# 34/34 [==============================] - 0s 760us/step - loss: 54.9269
# Epoch 52/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 54.6929
# Epoch 53/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 54.4603
# Epoch 54/1000
# 34/34 [==============================] - 0s 835us/step - loss: 54.2295
# Epoch 55/1000
# 34/34 [==============================] - 0s 913us/step - loss: 54.0008
# Epoch 56/1000
# 34/34 [==============================] - 0s 771us/step - loss: 53.7629
# Epoch 57/1000
# 34/34 [==============================] - 0s 799us/step - loss: 53.5416
# Epoch 58/1000
# 34/34 [==============================] - 0s 775us/step - loss: 53.2848
# Epoch 59/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 53.0560
# Epoch 60/1000
# 34/34 [==============================] - 0s 970us/step - loss: 52.8178
# Epoch 61/1000
# 34/34 [==============================] - 0s 810us/step - loss: 52.5685
# Epoch 62/1000
# 34/34 [==============================] - 0s 787us/step - loss: 52.3299
# Epoch 63/1000
# 34/34 [==============================] - 0s 805us/step - loss: 52.0760
# Epoch 64/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 51.8374
# Epoch 65/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 51.5859
# Epoch 66/1000
# 34/34 [==============================] - 0s 864us/step - loss: 51.3508
# Epoch 67/1000
# 34/34 [==============================] - 0s 781us/step - loss: 51.1068
# Epoch 68/1000
# 34/34 [==============================] - 0s 801us/step - loss: 50.8699
# Epoch 69/1000
# 34/34 [==============================] - 0s 810us/step - loss: 50.6289
# Epoch 70/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 50.3759
# Epoch 71/1000
# 34/34 [==============================] - 0s 932us/step - loss: 50.1618
# Epoch 72/1000
# 34/34 [==============================] - 0s 923us/step - loss: 49.9447
# Epoch 73/1000
# 34/34 [==============================] - 0s 838us/step - loss: 49.7730
# Epoch 74/1000
# 34/34 [==============================] - 0s 804us/step - loss: 49.5344
# Epoch 75/1000
# 34/34 [==============================] - 0s 752us/step - loss: 49.3678
# Epoch 76/1000
# 34/34 [==============================] - 0s 813us/step - loss: 49.1817
# Epoch 77/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 49.0065
# Epoch 78/1000
# 34/34 [==============================] - 0s 873us/step - loss: 48.8132
# Epoch 79/1000
# 34/34 [==============================] - 0s 843us/step - loss: 48.6208
# Epoch 80/1000
# 34/34 [==============================] - 0s 807us/step - loss: 48.4704
# Epoch 81/1000
# 34/34 [==============================] - 0s 822us/step - loss: 48.3049
# Epoch 82/1000
# 34/34 [==============================] - 0s 824us/step - loss: 48.1311
# Epoch 83/1000
# 34/34 [==============================] - 0s 783us/step - loss: 47.9841
# Epoch 84/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 47.8115
# Epoch 85/1000
# 34/34 [==============================] - 0s 890us/step - loss: 47.6643
# Epoch 86/1000
# 34/34 [==============================] - 0s 982us/step - loss: 47.5155
# Epoch 87/1000
# 34/34 [==============================] - 0s 872us/step - loss: 47.3866
# Epoch 88/1000
# 34/34 [==============================] - 0s 796us/step - loss: 47.2307
# Epoch 89/1000
# 34/34 [==============================] - 0s 764us/step - loss: 47.0769
# Epoch 90/1000
# 34/34 [==============================] - 0s 876us/step - loss: 46.9407
# Epoch 91/1000
# 34/34 [==============================] - 0s 818us/step - loss: 46.8144
# Epoch 92/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 46.6621
# Epoch 93/1000
# 34/34 [==============================] - 0s 920us/step - loss: 46.5718
# Epoch 94/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 46.4055
# Epoch 95/1000
# 34/34 [==============================] - 0s 797us/step - loss: 46.2839
# Epoch 96/1000
# 34/34 [==============================] - 0s 779us/step - loss: 46.1431
# Epoch 97/1000
# 34/34 [==============================] - 0s 794us/step - loss: 46.0209
# Epoch 98/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 45.9002
# Epoch 99/1000
# 34/34 [==============================] - 0s 890us/step - loss: 45.7956
# Epoch 100/1000
# 34/34 [==============================] - 0s 901us/step - loss: 45.6705
# Epoch 101/1000
# 34/34 [==============================] - 0s 880us/step - loss: 45.5568
# Epoch 102/1000
# 34/34 [==============================] - 0s 784us/step - loss: 45.4679
# Epoch 103/1000
# 34/34 [==============================] - 0s 754us/step - loss: 45.3272
# Epoch 104/1000
# 34/34 [==============================] - 0s 799us/step - loss: 45.2291
# Epoch 105/1000
# 34/34 [==============================] - 0s 987us/step - loss: 45.1332
# Epoch 106/1000
# 34/34 [==============================] - 0s 876us/step - loss: 45.0253
# Epoch 107/1000
# 34/34 [==============================] - 0s 744us/step - loss: 44.9362
# Epoch 108/1000
# 34/34 [==============================] - 0s 783us/step - loss: 44.8410
# Epoch 109/1000
# 34/34 [==============================] - 0s 892us/step - loss: 44.7421
# Epoch 110/1000
# 34/34 [==============================] - 0s 829us/step - loss: 44.6336
# Epoch 111/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 44.5575
# Epoch 112/1000
# 34/34 [==============================] - 0s 935us/step - loss: 44.4707
# Epoch 113/1000
# 34/34 [==============================] - 0s 885us/step - loss: 44.3766
# Epoch 114/1000
# 34/34 [==============================] - 0s 782us/step - loss: 44.2865
# Epoch 115/1000
# 34/34 [==============================] - 0s 834us/step - loss: 44.2191
# Epoch 116/1000
# 34/34 [==============================] - 0s 847us/step - loss: 44.1025
# Epoch 117/1000
# 34/34 [==============================] - 0s 810us/step - loss: 44.0212
# Epoch 118/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 43.9552
# Epoch 119/1000
# 34/34 [==============================] - 0s 996us/step - loss: 43.8602
# Epoch 120/1000
# 34/34 [==============================] - 0s 899us/step - loss: 43.7714
# Epoch 121/1000
# 34/34 [==============================] - 0s 794us/step - loss: 43.6894
# Epoch 122/1000
# 34/34 [==============================] - 0s 778us/step - loss: 43.6138
# Epoch 123/1000
# 34/34 [==============================] - 0s 787us/step - loss: 43.5468
# Epoch 124/1000
# 34/34 [==============================] - 0s 814us/step - loss: 43.4675
# Epoch 125/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 43.3853
# Epoch 126/1000
# 34/34 [==============================] - 0s 930us/step - loss: 43.3102
# Epoch 127/1000
# 34/34 [==============================] - 0s 977us/step - loss: 43.2314
# Epoch 128/1000
# 34/34 [==============================] - 0s 807us/step - loss: 43.1600
# Epoch 129/1000
# 34/34 [==============================] - 0s 811us/step - loss: 43.0791
# Epoch 130/1000
# 34/34 [==============================] - 0s 779us/step - loss: 43.0174
# Epoch 131/1000
# 34/34 [==============================] - 0s 783us/step - loss: 42.9377
# Epoch 132/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 42.8769
# Epoch 133/1000
# 34/34 [==============================] - 0s 848us/step - loss: 42.7898
# Epoch 134/1000
# 34/34 [==============================] - 0s 997us/step - loss: 42.7230
# Epoch 135/1000
# 34/34 [==============================] - 0s 934us/step - loss: 42.6547
# Epoch 136/1000
# 34/34 [==============================] - 0s 854us/step - loss: 42.5771
# Epoch 137/1000
# 34/34 [==============================] - 0s 841us/step - loss: 42.5167
# Epoch 138/1000
# 34/34 [==============================] - 0s 756us/step - loss: 42.4393
# Epoch 139/1000
# 34/34 [==============================] - 0s 960us/step - loss: 42.3797
# Epoch 140/1000
# 34/34 [==============================] - 0s 794us/step - loss: 42.3144
# Epoch 141/1000
# 34/34 [==============================] - 0s 785us/step - loss: 42.2604
# Epoch 142/1000
# 34/34 [==============================] - 0s 964us/step - loss: 42.1777
# Epoch 143/1000
# 34/34 [==============================] - 0s 771us/step - loss: 42.1081
# Epoch 144/1000
# 34/34 [==============================] - 0s 776us/step - loss: 42.0452
# Epoch 145/1000
# 34/34 [==============================] - 0s 755us/step - loss: 41.9885
# Epoch 146/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 41.9298
# Epoch 147/1000
# 34/34 [==============================] - 0s 900us/step - loss: 41.8437
# Epoch 148/1000
# 34/34 [==============================] - 0s 898us/step - loss: 41.7711
# Epoch 149/1000
# 34/34 [==============================] - 0s 914us/step - loss: 41.7354
# Epoch 150/1000
# 34/34 [==============================] - 0s 768us/step - loss: 41.6604
# Epoch 151/1000
# 34/34 [==============================] - 0s 742us/step - loss: 41.5965
# Epoch 152/1000
# 34/34 [==============================] - 0s 840us/step - loss: 41.5355
# Epoch 153/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 41.4894
# Epoch 154/1000
# 34/34 [==============================] - 0s 898us/step - loss: 41.4154
# Epoch 155/1000
# 34/34 [==============================] - 0s 789us/step - loss: 41.3527
# Epoch 156/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 41.3072
# Epoch 157/1000
# 34/34 [==============================] - 0s 837us/step - loss: 41.2396
# Epoch 158/1000
# 34/34 [==============================] - 0s 764us/step - loss: 41.1946
# Epoch 159/1000
# 34/34 [==============================] - 0s 820us/step - loss: 41.1354
# Epoch 160/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 41.0844
# Epoch 161/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 41.0470
# Epoch 162/1000
# 34/34 [==============================] - 0s 868us/step - loss: 40.9936
# Epoch 163/1000
# 34/34 [==============================] - 0s 782us/step - loss: 40.9166
# Epoch 164/1000
# 34/34 [==============================] - 0s 790us/step - loss: 40.8769
# Epoch 165/1000
# 34/34 [==============================] - 0s 759us/step - loss: 40.8215
# Epoch 166/1000
# 34/34 [==============================] - 0s 770us/step - loss: 40.7907
# Epoch 167/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 40.7409
# Epoch 168/1000
# 34/34 [==============================] - 0s 898us/step - loss: 40.6805
# Epoch 169/1000
# 34/34 [==============================] - 0s 938us/step - loss: 40.6425
# Epoch 170/1000
# 34/34 [==============================] - 0s 817us/step - loss: 40.5856
# Epoch 171/1000
# 34/34 [==============================] - 0s 798us/step - loss: 40.5431
# Epoch 172/1000
# 34/34 [==============================] - 0s 810us/step - loss: 40.5319
# Epoch 173/1000
# 34/34 [==============================] - 0s 773us/step - loss: 40.4573
# Epoch 174/1000
# 34/34 [==============================] - 0s 814us/step - loss: 40.4051
# Epoch 175/1000
# 34/34 [==============================] - 0s 949us/step - loss: 40.3586
# Epoch 176/1000
# 34/34 [==============================] - 0s 971us/step - loss: 40.3124
# Epoch 177/1000
# 34/34 [==============================] - 0s 922us/step - loss: 40.2523
# Epoch 178/1000
# 34/34 [==============================] - 0s 958us/step - loss: 40.2062
# Epoch 179/1000
# 34/34 [==============================] - 0s 779us/step - loss: 40.1665
# Epoch 180/1000
# 34/34 [==============================] - 0s 853us/step - loss: 40.1267
# Epoch 181/1000
# 34/34 [==============================] - 0s 824us/step - loss: 40.0717
# Epoch 182/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 40.0309
# Epoch 183/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 39.9802
# Epoch 184/1000
# 34/34 [==============================] - 0s 903us/step - loss: 39.9546
# Epoch 185/1000
# 34/34 [==============================] - 0s 914us/step - loss: 39.9202
# Epoch 186/1000
# 34/34 [==============================] - 0s 975us/step - loss: 39.8598
# Epoch 187/1000
# 34/34 [==============================] - 0s 767us/step - loss: 39.8081
# Epoch 188/1000
# 34/34 [==============================] - 0s 787us/step - loss: 39.7714
# Epoch 189/1000
# 34/34 [==============================] - 0s 781us/step - loss: 39.7422
# Epoch 190/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 39.7072
# Epoch 191/1000
# 34/34 [==============================] - 0s 989us/step - loss: 39.6521
# Epoch 192/1000
# 34/34 [==============================] - 0s 973us/step - loss: 39.5998
# Epoch 193/1000
# 34/34 [==============================] - 0s 759us/step - loss: 39.5768
# Epoch 194/1000
# 34/34 [==============================] - 0s 926us/step - loss: 39.5279
# Epoch 195/1000
# 34/34 [==============================] - 0s 773us/step - loss: 39.4840
# Epoch 196/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 39.4515
# Epoch 197/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 39.4090
# Epoch 198/1000
# 34/34 [==============================] - 0s 992us/step - loss: 39.3945
# Epoch 199/1000
# 34/34 [==============================] - 0s 762us/step - loss: 39.3296
# Epoch 200/1000
# 34/34 [==============================] - 0s 774us/step - loss: 39.2932
# Epoch 201/1000
# 34/34 [==============================] - 0s 768us/step - loss: 39.2649
# Epoch 202/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 39.2095
# Epoch 203/1000
# 34/34 [==============================] - 0s 924us/step - loss: 39.1636
# Epoch 204/1000
# 34/34 [==============================] - 0s 879us/step - loss: 39.1308
# Epoch 205/1000
# 34/34 [==============================] - 0s 973us/step - loss: 39.0941
# Epoch 206/1000
# 34/34 [==============================] - 0s 842us/step - loss: 39.0501
# Epoch 207/1000
# 34/34 [==============================] - 0s 799us/step - loss: 39.0270
# Epoch 208/1000
# 34/34 [==============================] - 0s 747us/step - loss: 38.9819
# Epoch 209/1000
# 34/34 [==============================] - 0s 758us/step - loss: 38.9441
# Epoch 210/1000
# 34/34 [==============================] - 0s 856us/step - loss: 38.8987
# Epoch 211/1000
# 34/34 [==============================] - 0s 935us/step - loss: 38.8709
# Epoch 212/1000
# 34/34 [==============================] - 0s 980us/step - loss: 38.8571
# Epoch 213/1000
# 34/34 [==============================] - 0s 787us/step - loss: 38.8029
# Epoch 214/1000
# 34/34 [==============================] - 0s 760us/step - loss: 38.7511
# Epoch 215/1000
# 34/34 [==============================] - 0s 774us/step - loss: 38.7247
# Epoch 216/1000
# 34/34 [==============================] - 0s 778us/step - loss: 38.6761
# Epoch 217/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 38.6448
# Epoch 218/1000
# 34/34 [==============================] - 0s 955us/step - loss: 38.6060
# Epoch 219/1000
# 34/34 [==============================] - 0s 942us/step - loss: 38.5784
# Epoch 220/1000
# 34/34 [==============================] - 0s 943us/step - loss: 38.5584
# Epoch 221/1000
# 34/34 [==============================] - 0s 785us/step - loss: 38.5078
# Epoch 222/1000
# 34/34 [==============================] - 0s 771us/step - loss: 38.4823
# Epoch 223/1000
# 34/34 [==============================] - 0s 738us/step - loss: 38.4491
# Epoch 224/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 38.4253
# Epoch 225/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 38.3791
# Epoch 226/1000
# 34/34 [==============================] - 0s 844us/step - loss: 38.3469
# Epoch 227/1000
# 34/34 [==============================] - 0s 770us/step - loss: 38.3159
# Epoch 228/1000
# 34/34 [==============================] - 0s 739us/step - loss: 38.2955
# Epoch 229/1000
# 34/34 [==============================] - 0s 800us/step - loss: 38.2516
# Epoch 230/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 38.2180
# Epoch 231/1000
# 34/34 [==============================] - 0s 966us/step - loss: 38.1933
# Epoch 232/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 38.1490
# Epoch 233/1000
# 34/34 [==============================] - 0s 795us/step - loss: 38.1162
# Epoch 234/1000
# 34/34 [==============================] - 0s 756us/step - loss: 38.0889
# Epoch 235/1000
# 34/34 [==============================] - 0s 764us/step - loss: 38.0598
# Epoch 236/1000
# 34/34 [==============================] - 0s 831us/step - loss: 38.0265
# Epoch 237/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 37.9938
# Epoch 238/1000
# 34/34 [==============================] - 0s 888us/step - loss: 37.9750
# Epoch 239/1000
# 34/34 [==============================] - 0s 892us/step - loss: 37.9300
# Epoch 240/1000
# 34/34 [==============================] - 0s 970us/step - loss: 37.8950
# Epoch 241/1000
# 34/34 [==============================] - 0s 784us/step - loss: 37.8804
# Epoch 242/1000
# 34/34 [==============================] - 0s 824us/step - loss: 37.8761
# Epoch 243/1000
# 34/34 [==============================] - 0s 827us/step - loss: 37.8380
# Epoch 244/1000
# 34/34 [==============================] - 0s 768us/step - loss: 37.7654
# Epoch 245/1000
# 34/34 [==============================] - 0s 978us/step - loss: 37.7457
# Epoch 246/1000
# 34/34 [==============================] - 0s 933us/step - loss: 37.7252
# Epoch 247/1000
# 34/34 [==============================] - 0s 983us/step - loss: 37.6900
# Epoch 248/1000
# 34/34 [==============================] - 0s 960us/step - loss: 37.6677
# Epoch 249/1000
# 34/34 [==============================] - 0s 804us/step - loss: 37.6426
# Epoch 250/1000
# 34/34 [==============================] - 0s 792us/step - loss: 37.6031
# Epoch 251/1000
# 34/34 [==============================] - 0s 823us/step - loss: 37.5838
# Epoch 252/1000
# 34/34 [==============================] - 0s 790us/step - loss: 37.5572
# Epoch 253/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 37.5334
# Epoch 254/1000
# 34/34 [==============================] - 0s 902us/step - loss: 37.4958
# Epoch 255/1000
# 34/34 [==============================] - 0s 943us/step - loss: 37.4600
# Epoch 256/1000
# 34/34 [==============================] - 0s 763us/step - loss: 37.4341
# Epoch 257/1000
# 34/34 [==============================] - 0s 764us/step - loss: 37.4181
# Epoch 258/1000
# 34/34 [==============================] - 0s 770us/step - loss: 37.3760
# Epoch 259/1000
# 34/34 [==============================] - 0s 764us/step - loss: 37.3507
# Epoch 260/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 37.3416
# Epoch 261/1000
# 34/34 [==============================] - 0s 981us/step - loss: 37.3022
# Epoch 262/1000
# 34/34 [==============================] - 0s 884us/step - loss: 37.2794
# Epoch 263/1000
# 34/34 [==============================] - 0s 743us/step - loss: 37.2391
# Epoch 264/1000
# 34/34 [==============================] - 0s 766us/step - loss: 37.2266
# Epoch 265/1000
# 34/34 [==============================] - 0s 844us/step - loss: 37.1877
# Epoch 266/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 37.1701
# Epoch 267/1000
# 34/34 [==============================] - 0s 935us/step - loss: 37.1581
# Epoch 268/1000
# 34/34 [==============================] - 0s 919us/step - loss: 37.1108
# Epoch 269/1000
# 34/34 [==============================] - 0s 934us/step - loss: 37.0803
# Epoch 270/1000
# 34/34 [==============================] - 0s 838us/step - loss: 37.0667
# Epoch 271/1000
# 34/34 [==============================] - 0s 792us/step - loss: 37.0308
# Epoch 272/1000
# 34/34 [==============================] - 0s 846us/step - loss: 37.0016
# Epoch 273/1000
# 34/34 [==============================] - 0s 822us/step - loss: 36.9766
# Epoch 274/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.9737
# Epoch 275/1000
# 34/34 [==============================] - 0s 956us/step - loss: 36.9591
# Epoch 276/1000
# 34/34 [==============================] - 0s 963us/step - loss: 36.9043
# Epoch 277/1000
# 34/34 [==============================] - 0s 822us/step - loss: 36.8833
# Epoch 278/1000
# 34/34 [==============================] - 0s 793us/step - loss: 36.8535
# Epoch 279/1000
# 34/34 [==============================] - 0s 785us/step - loss: 36.8287
# Epoch 280/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.7977
# Epoch 281/1000
# 34/34 [==============================] - 0s 980us/step - loss: 36.7861
# Epoch 282/1000
# 34/34 [==============================] - 0s 891us/step - loss: 36.7509
# Epoch 283/1000
# 34/34 [==============================] - 0s 771us/step - loss: 36.7256
# Epoch 284/1000
# 34/34 [==============================] - 0s 755us/step - loss: 36.6983
# Epoch 285/1000
# 34/34 [==============================] - 0s 784us/step - loss: 36.6815
# Epoch 286/1000
# 34/34 [==============================] - 0s 819us/step - loss: 36.6468
# Epoch 287/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.6358
# Epoch 288/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.6139
# Epoch 289/1000
# 34/34 [==============================] - 0s 862us/step - loss: 36.5760
# Epoch 290/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.5591
# Epoch 291/1000
# 34/34 [==============================] - 0s 812us/step - loss: 36.5276
# Epoch 292/1000
# 34/34 [==============================] - 0s 770us/step - loss: 36.5115
# Epoch 293/1000
# 34/34 [==============================] - 0s 796us/step - loss: 36.4769
# Epoch 294/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.4636
# Epoch 295/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.4326
# Epoch 296/1000
# 34/34 [==============================] - 0s 972us/step - loss: 36.4116
# Epoch 297/1000
# 34/34 [==============================] - 0s 881us/step - loss: 36.3895
# Epoch 298/1000
# 34/34 [==============================] - 0s 743us/step - loss: 36.3715
# Epoch 299/1000
# 34/34 [==============================] - 0s 786us/step - loss: 36.3420
# Epoch 300/1000
# 34/34 [==============================] - 0s 736us/step - loss: 36.3178
# Epoch 301/1000
# 34/34 [==============================] - 0s 777us/step - loss: 36.2982
# Epoch 302/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.2727
# Epoch 303/1000
# 34/34 [==============================] - 0s 871us/step - loss: 36.2547
# Epoch 304/1000
# 34/34 [==============================] - 0s 947us/step - loss: 36.2432
# Epoch 305/1000
# 34/34 [==============================] - 0s 986us/step - loss: 36.2131
# Epoch 306/1000
# 34/34 [==============================] - 0s 754us/step - loss: 36.1939
# Epoch 307/1000
# 34/34 [==============================] - 0s 801us/step - loss: 36.1849
# Epoch 308/1000
# 34/34 [==============================] - 0s 812us/step - loss: 36.1402
# Epoch 309/1000
# 34/34 [==============================] - 0s 737us/step - loss: 36.1302
# Epoch 310/1000
# 34/34 [==============================] - 0s 794us/step - loss: 36.0986
# Epoch 311/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 36.0823
# Epoch 312/1000
# 34/34 [==============================] - 0s 984us/step - loss: 36.0526
# Epoch 313/1000
# 34/34 [==============================] - 0s 947us/step - loss: 36.0349
# Epoch 314/1000
# 34/34 [==============================] - 0s 834us/step - loss: 36.0112
# Epoch 315/1000
# 34/34 [==============================] - 0s 774us/step - loss: 36.0031
# Epoch 316/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.9766
# Epoch 317/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.9514
# Epoch 318/1000
# 34/34 [==============================] - 0s 874us/step - loss: 35.9438
# Epoch 319/1000
# 34/34 [==============================] - 0s 799us/step - loss: 35.9263
# Epoch 320/1000
# 34/34 [==============================] - 0s 798us/step - loss: 35.8951
# Epoch 321/1000
# 34/34 [==============================] - 0s 782us/step - loss: 35.8894
# Epoch 322/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.8546
# Epoch 323/1000
# 34/34 [==============================] - 0s 879us/step - loss: 35.8509
# Epoch 324/1000
# 34/34 [==============================] - 0s 896us/step - loss: 35.8231
# Epoch 325/1000
# 34/34 [==============================] - 0s 838us/step - loss: 35.8148
# Epoch 326/1000
# 34/34 [==============================] - 0s 810us/step - loss: 35.7805
# Epoch 327/1000
# 34/34 [==============================] - 0s 824us/step - loss: 35.7676
# Epoch 328/1000
# 34/34 [==============================] - 0s 819us/step - loss: 35.7502
# Epoch 329/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.7219
# Epoch 330/1000
# 34/34 [==============================] - 0s 936us/step - loss: 35.7057
# Epoch 331/1000
# 34/34 [==============================] - 0s 853us/step - loss: 35.6837
# Epoch 332/1000
# 34/34 [==============================] - 0s 808us/step - loss: 35.6688
# Epoch 333/1000
# 34/34 [==============================] - 0s 817us/step - loss: 35.6512
# Epoch 334/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.6335
# Epoch 335/1000
# 34/34 [==============================] - 0s 892us/step - loss: 35.6092
# Epoch 336/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.5967
# Epoch 337/1000
# 34/34 [==============================] - 0s 808us/step - loss: 35.5782
# Epoch 338/1000
# 34/34 [==============================] - 0s 758us/step - loss: 35.5565
# Epoch 339/1000
# 34/34 [==============================] - 0s 932us/step - loss: 35.5399
# Epoch 340/1000
# 34/34 [==============================] - 0s 767us/step - loss: 35.5252
# Epoch 341/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.5088
# Epoch 342/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.4902
# Epoch 343/1000
# 34/34 [==============================] - 0s 832us/step - loss: 35.4793
# Epoch 344/1000
# 34/34 [==============================] - 0s 852us/step - loss: 35.4463
# Epoch 345/1000
# 34/34 [==============================] - 0s 866us/step - loss: 35.4310
# Epoch 346/1000
# 34/34 [==============================] - 0s 789us/step - loss: 35.4371
# Epoch 347/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.4275
# Epoch 348/1000
# 34/34 [==============================] - 0s 948us/step - loss: 35.3837
# Epoch 349/1000
# 34/34 [==============================] - 0s 971us/step - loss: 35.3645
# Epoch 350/1000
# 34/34 [==============================] - 0s 834us/step - loss: 35.3626
# Epoch 351/1000
# 34/34 [==============================] - 0s 908us/step - loss: 35.3259
# Epoch 352/1000
# 34/34 [==============================] - 0s 788us/step - loss: 35.3139
# Epoch 353/1000
# 34/34 [==============================] - 0s 814us/step - loss: 35.2963
# Epoch 354/1000
# 34/34 [==============================] - 0s 801us/step - loss: 35.2724
# Epoch 355/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.2607
# Epoch 356/1000
# 34/34 [==============================] - 0s 994us/step - loss: 35.2491
# Epoch 357/1000
# 34/34 [==============================] - 0s 845us/step - loss: 35.2333
# Epoch 358/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.2144
# Epoch 359/1000
# 34/34 [==============================] - 0s 841us/step - loss: 35.2078
# Epoch 360/1000
# 34/34 [==============================] - 0s 799us/step - loss: 35.1933
# Epoch 361/1000
# 34/34 [==============================] - 0s 773us/step - loss: 35.1681
# Epoch 362/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.1527
# Epoch 363/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.1528
# Epoch 364/1000
# 34/34 [==============================] - 0s 800us/step - loss: 35.1306
# Epoch 365/1000
# 34/34 [==============================] - 0s 794us/step - loss: 35.1080
# Epoch 366/1000
# 34/34 [==============================] - 0s 795us/step - loss: 35.0866
# Epoch 367/1000
# 34/34 [==============================] - 0s 761us/step - loss: 35.0749
# Epoch 368/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.0653
# Epoch 369/1000
# 34/34 [==============================] - 0s 859us/step - loss: 35.0420
# Epoch 370/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 35.0369
# Epoch 371/1000
# 34/34 [==============================] - 0s 898us/step - loss: 35.0217
# Epoch 372/1000
# 34/34 [==============================] - 0s 816us/step - loss: 35.0075
# Epoch 373/1000
# 34/34 [==============================] - 0s 798us/step - loss: 34.9955
# Epoch 374/1000
# 34/34 [==============================] - 0s 769us/step - loss: 34.9651
# Epoch 375/1000
# 34/34 [==============================] - 0s 783us/step - loss: 34.9471
# Epoch 376/1000
# 34/34 [==============================] - 0s 735us/step - loss: 34.9354
# Epoch 377/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.9269
# Epoch 378/1000
# 34/34 [==============================] - 0s 954us/step - loss: 34.9033
# Epoch 379/1000
# 34/34 [==============================] - 0s 877us/step - loss: 34.8865
# Epoch 380/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.8711
# Epoch 381/1000
# 34/34 [==============================] - 0s 780us/step - loss: 34.8509
# Epoch 382/1000
# 34/34 [==============================] - 0s 836us/step - loss: 34.8326
# Epoch 383/1000
# 34/34 [==============================] - 0s 805us/step - loss: 34.8236
# Epoch 384/1000
# 34/34 [==============================] - 0s 770us/step - loss: 34.8136
# Epoch 385/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.7846
# Epoch 386/1000
# 34/34 [==============================] - 0s 955us/step - loss: 34.7710
# Epoch 387/1000
# 34/34 [==============================] - 0s 890us/step - loss: 34.7520
# Epoch 388/1000
# 34/34 [==============================] - 0s 959us/step - loss: 34.7336
# Epoch 389/1000
# 34/34 [==============================] - 0s 790us/step - loss: 34.7224
# Epoch 390/1000
# 34/34 [==============================] - 0s 821us/step - loss: 34.6976
# Epoch 391/1000
# 34/34 [==============================] - 0s 788us/step - loss: 34.6898
# Epoch 392/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.6685
# Epoch 393/1000
# 34/34 [==============================] - 0s 911us/step - loss: 34.6495
# Epoch 394/1000
# 34/34 [==============================] - 0s 888us/step - loss: 34.6303
# Epoch 395/1000
# 34/34 [==============================] - 0s 900us/step - loss: 34.6278
# Epoch 396/1000
# 34/34 [==============================] - 0s 787us/step - loss: 34.5987
# Epoch 397/1000
# 34/34 [==============================] - 0s 815us/step - loss: 34.6038
# Epoch 398/1000
# 34/34 [==============================] - 0s 776us/step - loss: 34.5704
# Epoch 399/1000
# 34/34 [==============================] - 0s 842us/step - loss: 34.5549
# Epoch 400/1000
# 34/34 [==============================] - 0s 819us/step - loss: 34.5371
# Epoch 401/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.5239
# Epoch 402/1000
# 34/34 [==============================] - 0s 835us/step - loss: 34.5068
# Epoch 403/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.5181
# Epoch 404/1000
# 34/34 [==============================] - 0s 769us/step - loss: 34.4888
# Epoch 405/1000
# 34/34 [==============================] - 0s 844us/step - loss: 34.4536
# Epoch 406/1000
# 34/34 [==============================] - 0s 853us/step - loss: 34.4385
# Epoch 407/1000
# 34/34 [==============================] - 0s 891us/step - loss: 34.4467
# Epoch 408/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.4168
# Epoch 409/1000
# 34/34 [==============================] - 0s 878us/step - loss: 34.4049
# Epoch 410/1000
# 34/34 [==============================] - 0s 866us/step - loss: 34.3796
# Epoch 411/1000
# 34/34 [==============================] - 0s 933us/step - loss: 34.3556
# Epoch 412/1000
# 34/34 [==============================] - 0s 830us/step - loss: 34.3503
# Epoch 413/1000
# 34/34 [==============================] - 0s 792us/step - loss: 34.3398
# Epoch 414/1000
# 34/34 [==============================] - 0s 780us/step - loss: 34.3156
# Epoch 415/1000
# 34/34 [==============================] - 0s 757us/step - loss: 34.2912
# Epoch 416/1000
# 34/34 [==============================] - 0s 789us/step - loss: 34.2738
# Epoch 417/1000
# 34/34 [==============================] - 0s 997us/step - loss: 34.2601
# Epoch 418/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.2548
# Epoch 419/1000
# 34/34 [==============================] - 0s 946us/step - loss: 34.2306
# Epoch 420/1000
# 34/34 [==============================] - 0s 828us/step - loss: 34.2287
# Epoch 421/1000
# 34/34 [==============================] - 0s 805us/step - loss: 34.2011
# Epoch 422/1000
# 34/34 [==============================] - 0s 793us/step - loss: 34.1933
# Epoch 423/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.1720
# Epoch 424/1000
# 34/34 [==============================] - 0s 963us/step - loss: 34.1621
# Epoch 425/1000
# 34/34 [==============================] - 0s 934us/step - loss: 34.1502
# Epoch 426/1000
# 34/34 [==============================] - 0s 867us/step - loss: 34.1241
# Epoch 427/1000
# 34/34 [==============================] - 0s 769us/step - loss: 34.1199
# Epoch 428/1000
# 34/34 [==============================] - 0s 777us/step - loss: 34.1098
# Epoch 429/1000
# 34/34 [==============================] - 0s 763us/step - loss: 34.0874
# Epoch 430/1000
# 34/34 [==============================] - 0s 773us/step - loss: 34.0747
# Epoch 431/1000
# 34/34 [==============================] - 0s 961us/step - loss: 34.0586
# Epoch 432/1000
# 34/34 [==============================] - 0s 905us/step - loss: 34.0474
# Epoch 433/1000
# 34/34 [==============================] - 0s 961us/step - loss: 34.0374
# Epoch 434/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 34.0127
# Epoch 435/1000
# 34/34 [==============================] - 0s 797us/step - loss: 34.0000
# Epoch 436/1000
# 34/34 [==============================] - 0s 773us/step - loss: 33.9865
# Epoch 437/1000
# 34/34 [==============================] - 0s 771us/step - loss: 33.9718
# Epoch 438/1000
# 34/34 [==============================] - 0s 742us/step - loss: 33.9605
# Epoch 439/1000
# 34/34 [==============================] - 0s 743us/step - loss: 33.9478
# Epoch 440/1000
# 34/34 [==============================] - 0s 998us/step - loss: 33.9321
# Epoch 441/1000
# 34/34 [==============================] - 0s 961us/step - loss: 33.9245
# Epoch 442/1000
# 34/34 [==============================] - 0s 914us/step - loss: 33.9170
# Epoch 443/1000
# 34/34 [==============================] - 0s 835us/step - loss: 33.8958
# Epoch 444/1000
# 34/34 [==============================] - 0s 729us/step - loss: 33.8760
# Epoch 445/1000
# 34/34 [==============================] - 0s 790us/step - loss: 33.8650
# Epoch 446/1000
# 34/34 [==============================] - 0s 875us/step - loss: 33.8562
# Epoch 447/1000
# 34/34 [==============================] - 0s 759us/step - loss: 33.8375
# Epoch 448/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.8232
# Epoch 449/1000
# 34/34 [==============================] - 0s 989us/step - loss: 33.8139
# Epoch 450/1000
# 34/34 [==============================] - 0s 743us/step - loss: 33.8007
# Epoch 451/1000
# 34/34 [==============================] - 0s 770us/step - loss: 33.7884
# Epoch 452/1000
# 34/34 [==============================] - 0s 768us/step - loss: 33.7748
# Epoch 453/1000
# 34/34 [==============================] - 0s 759us/step - loss: 33.7665
# Epoch 454/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.7538
# Epoch 455/1000
# 34/34 [==============================] - 0s 899us/step - loss: 33.7599
# Epoch 456/1000
# 34/34 [==============================] - 0s 893us/step - loss: 33.7271
# Epoch 457/1000
# 34/34 [==============================] - 0s 888us/step - loss: 33.7156
# Epoch 458/1000
# 34/34 [==============================] - 0s 763us/step - loss: 33.6998
# Epoch 459/1000
# 34/34 [==============================] - 0s 769us/step - loss: 33.6923
# Epoch 460/1000
# 34/34 [==============================] - 0s 801us/step - loss: 33.6837
# Epoch 461/1000
# 34/34 [==============================] - 0s 857us/step - loss: 33.6612
# Epoch 462/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.6583
# Epoch 463/1000
# 34/34 [==============================] - 0s 844us/step - loss: 33.6298
# Epoch 464/1000
# 34/34 [==============================] - 0s 790us/step - loss: 33.6353
# Epoch 465/1000
# 34/34 [==============================] - 0s 789us/step - loss: 33.6316
# Epoch 466/1000
# 34/34 [==============================] - 0s 820us/step - loss: 33.5948
# Epoch 467/1000
# 34/34 [==============================] - 0s 854us/step - loss: 33.5921
# Epoch 468/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.5736
# Epoch 469/1000
# 34/34 [==============================] - 0s 945us/step - loss: 33.5772
# Epoch 470/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.5696
# Epoch 471/1000
# 34/34 [==============================] - 0s 810us/step - loss: 33.5427
# Epoch 472/1000
# 34/34 [==============================] - 0s 786us/step - loss: 33.5391
# Epoch 473/1000
# 34/34 [==============================] - 0s 753us/step - loss: 33.5112
# Epoch 474/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.5092
# Epoch 475/1000
# 34/34 [==============================] - 0s 935us/step - loss: 33.4954
# Epoch 476/1000
# 34/34 [==============================] - 0s 829us/step - loss: 33.5011
# Epoch 477/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.4689
# Epoch 478/1000
# 34/34 [==============================] - 0s 794us/step - loss: 33.4624
# Epoch 479/1000
# 34/34 [==============================] - 0s 878us/step - loss: 33.4516
# Epoch 480/1000
# 34/34 [==============================] - 0s 878us/step - loss: 33.4372
# Epoch 481/1000
# 34/34 [==============================] - 0s 848us/step - loss: 33.4270
# Epoch 482/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.4115
# Epoch 483/1000
# 34/34 [==============================] - 0s 927us/step - loss: 33.4160
# Epoch 484/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.4006
# Epoch 485/1000
# 34/34 [==============================] - 0s 789us/step - loss: 33.3757
# Epoch 486/1000
# 34/34 [==============================] - 0s 805us/step - loss: 33.3689
# Epoch 487/1000
# 34/34 [==============================] - 0s 821us/step - loss: 33.3530
# Epoch 488/1000
# 34/34 [==============================] - 0s 748us/step - loss: 33.3566
# Epoch 489/1000
# 34/34 [==============================] - 0s 750us/step - loss: 33.3293
# Epoch 490/1000
# 34/34 [==============================] - 0s 917us/step - loss: 33.3252
# Epoch 491/1000
# 34/34 [==============================] - 0s 912us/step - loss: 33.3114
# Epoch 492/1000
# 34/34 [==============================] - 0s 797us/step - loss: 33.3060
# Epoch 493/1000
# 34/34 [==============================] - 0s 877us/step - loss: 33.2944
# Epoch 494/1000
# 34/34 [==============================] - 0s 778us/step - loss: 33.2769
# Epoch 495/1000
# 34/34 [==============================] - 0s 792us/step - loss: 33.2908
# Epoch 496/1000
# 34/34 [==============================] - 0s 822us/step - loss: 33.2576
# Epoch 497/1000
# 34/34 [==============================] - 0s 779us/step - loss: 33.2411
# Epoch 498/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.2354
# Epoch 499/1000
# 34/34 [==============================] - 0s 892us/step - loss: 33.2181
# Epoch 500/1000
# 34/34 [==============================] - 0s 842us/step - loss: 33.2078
# Epoch 501/1000
# 34/34 [==============================] - 0s 772us/step - loss: 33.1978
# Epoch 502/1000
# 34/34 [==============================] - 0s 773us/step - loss: 33.1892
# Epoch 503/1000
# 34/34 [==============================] - 0s 792us/step - loss: 33.1828
# Epoch 504/1000
# 34/34 [==============================] - 0s 860us/step - loss: 33.1716
# Epoch 505/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.1528
# Epoch 506/1000
# 34/34 [==============================] - 0s 981us/step - loss: 33.1558
# Epoch 507/1000
# 34/34 [==============================] - 0s 835us/step - loss: 33.1313
# Epoch 508/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.1188
# Epoch 509/1000
# 34/34 [==============================] - 0s 778us/step - loss: 33.1193
# Epoch 510/1000
# 34/34 [==============================] - 0s 756us/step - loss: 33.0976
# Epoch 511/1000
# 34/34 [==============================] - 0s 784us/step - loss: 33.0818
# Epoch 512/1000
# 34/34 [==============================] - 0s 744us/step - loss: 33.0767
# Epoch 513/1000
# 34/34 [==============================] - 0s 781us/step - loss: 33.0661
# Epoch 514/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.0540
# Epoch 515/1000
# 34/34 [==============================] - 0s 910us/step - loss: 33.0408
# Epoch 516/1000
# 34/34 [==============================] - 0s 985us/step - loss: 33.0289
# Epoch 517/1000
# 34/34 [==============================] - 0s 829us/step - loss: 33.0238
# Epoch 518/1000
# 34/34 [==============================] - 0s 797us/step - loss: 33.0013
# Epoch 519/1000
# 34/34 [==============================] - 0s 817us/step - loss: 32.9917
# Epoch 520/1000
# 34/34 [==============================] - 0s 792us/step - loss: 32.9865
# Epoch 521/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 33.0015
# Epoch 522/1000
# 34/34 [==============================] - 0s 995us/step - loss: 32.9731
# Epoch 523/1000
# 34/34 [==============================] - 0s 844us/step - loss: 32.9544
# Epoch 524/1000
# 34/34 [==============================] - 0s 733us/step - loss: 32.9523
# Epoch 525/1000
# 34/34 [==============================] - 0s 755us/step - loss: 32.9336
# Epoch 526/1000
# 34/34 [==============================] - 0s 767us/step - loss: 32.9301
# Epoch 527/1000
# 34/34 [==============================] - 0s 805us/step - loss: 32.9188
# Epoch 528/1000
# 34/34 [==============================] - 0s 996us/step - loss: 32.9068
# Epoch 529/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.8903
# Epoch 530/1000
# 34/34 [==============================] - 0s 872us/step - loss: 32.8819
# Epoch 531/1000
# 34/34 [==============================] - 0s 805us/step - loss: 32.8796
# Epoch 532/1000
# 34/34 [==============================] - 0s 835us/step - loss: 32.8613
# Epoch 533/1000
# 34/34 [==============================] - 0s 845us/step - loss: 32.8537
# Epoch 534/1000
# 34/34 [==============================] - 0s 832us/step - loss: 32.8362
# Epoch 535/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.8536
# Epoch 536/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.8198
# Epoch 537/1000
# 34/34 [==============================] - 0s 896us/step - loss: 32.8107
# Epoch 538/1000
# 34/34 [==============================] - 0s 787us/step - loss: 32.7943
# Epoch 539/1000
# 34/34 [==============================] - 0s 811us/step - loss: 32.7923
# Epoch 540/1000
# 34/34 [==============================] - 0s 826us/step - loss: 32.7824
# Epoch 541/1000
# 34/34 [==============================] - 0s 956us/step - loss: 32.7759
# Epoch 542/1000
# 34/34 [==============================] - 0s 957us/step - loss: 32.7752
# Epoch 543/1000
# 34/34 [==============================] - 0s 820us/step - loss: 32.7569
# Epoch 544/1000
# 34/34 [==============================] - 0s 826us/step - loss: 32.7423
# Epoch 545/1000
# 34/34 [==============================] - 0s 808us/step - loss: 32.7553
# Epoch 546/1000
# 34/34 [==============================] - 0s 788us/step - loss: 32.7209
# Epoch 547/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.7205
# Epoch 548/1000
# 34/34 [==============================] - 0s 956us/step - loss: 32.7102
# Epoch 549/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.7068
# Epoch 550/1000
# 34/34 [==============================] - 0s 818us/step - loss: 32.6895
# Epoch 551/1000
# 34/34 [==============================] - 0s 784us/step - loss: 32.6821
# Epoch 552/1000
# 34/34 [==============================] - 0s 817us/step - loss: 32.6693
# Epoch 553/1000
# 34/34 [==============================] - 0s 985us/step - loss: 32.6630
# Epoch 554/1000
# 34/34 [==============================] - 0s 922us/step - loss: 32.6500
# Epoch 555/1000
# 34/34 [==============================] - 0s 916us/step - loss: 32.6428
# Epoch 556/1000
# 34/34 [==============================] - 0s 959us/step - loss: 32.6444
# Epoch 557/1000
# 34/34 [==============================] - 0s 785us/step - loss: 32.6289
# Epoch 558/1000
# 34/34 [==============================] - 0s 817us/step - loss: 32.6137
# Epoch 559/1000
# 34/34 [==============================] - 0s 818us/step - loss: 32.6121
# Epoch 560/1000
# 34/34 [==============================] - 0s 751us/step - loss: 32.5962
# Epoch 561/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 32.5965
# Epoch 562/1000
# ...
# Epoch 814/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.9485
# Epoch 815/1000
# 34/34 [==============================] - 0s 788us/step - loss: 30.9549
# Epoch 816/1000
# 34/34 [==============================] - 0s 764us/step - loss: 30.9343
# Epoch 817/1000
# 34/34 [==============================] - 0s 792us/step - loss: 30.9237
# Epoch 818/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.9298
# Epoch 819/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.9144
# Epoch 820/1000
# 34/34 [==============================] - 0s 754us/step - loss: 30.9183
# Epoch 821/1000
# 34/34 [==============================] - 0s 770us/step - loss: 30.9029
# Epoch 822/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8989
# Epoch 823/1000
# 34/34 [==============================] - 0s 926us/step - loss: 30.9037
# Epoch 824/1000
# 34/34 [==============================] - 0s 758us/step - loss: 30.8963
# Epoch 825/1000
# 34/34 [==============================] - 0s 792us/step - loss: 30.8999
# Epoch 826/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8892
# Epoch 827/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8814
# Epoch 828/1000
# 34/34 [==============================] - 0s 852us/step - loss: 30.8814
# Epoch 829/1000
# 34/34 [==============================] - 0s 823us/step - loss: 30.8731
# Epoch 830/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8685
# Epoch 831/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8644
# Epoch 832/1000
# 34/34 [==============================] - 0s 989us/step - loss: 30.8614
# Epoch 833/1000
# 34/34 [==============================] - 0s 800us/step - loss: 30.8508
# Epoch 834/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8422
# Epoch 835/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8393
# Epoch 836/1000
# 34/34 [==============================] - 0s 873us/step - loss: 30.8310
# Epoch 837/1000
# 34/34 [==============================] - 0s 788us/step - loss: 30.8290
# Epoch 838/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8226
# Epoch 839/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.8243
# Epoch 840/1000
# 34/34 [==============================] - 0s 905us/step - loss: 30.8164
# Epoch 841/1000
# 34/34 [==============================] - 0s 765us/step - loss: 30.8049
# Epoch 842/1000
# 34/34 [==============================] - 0s 782us/step - loss: 30.8189
# Epoch 843/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7999
# Epoch 844/1000
# 34/34 [==============================] - 0s 861us/step - loss: 30.8092
# Epoch 845/1000
# 34/34 [==============================] - 0s 758us/step - loss: 30.7920
# Epoch 846/1000
# 34/34 [==============================] - 0s 796us/step - loss: 30.7924
# Epoch 847/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7833
# Epoch 848/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7822
# Epoch 849/1000
# 34/34 [==============================] - 0s 766us/step - loss: 30.7728
# Epoch 850/1000
# 34/34 [==============================] - 0s 760us/step - loss: 30.7679
# Epoch 851/1000
# 34/34 [==============================] - 0s 771us/step - loss: 30.7587
# Epoch 852/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7565
# Epoch 853/1000
# 34/34 [==============================] - 0s 966us/step - loss: 30.7525
# Epoch 854/1000
# 34/34 [==============================] - 0s 820us/step - loss: 30.7495
# Epoch 855/1000
# 34/34 [==============================] - 0s 808us/step - loss: 30.7441
# Epoch 856/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7371
# Epoch 857/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7330
# Epoch 858/1000
# 34/34 [==============================] - 0s 888us/step - loss: 30.7298
# Epoch 859/1000
# 34/34 [==============================] - 0s 737us/step - loss: 30.7405
# Epoch 860/1000
# 34/34 [==============================] - 0s 755us/step - loss: 30.7233
# Epoch 861/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7200
# Epoch 862/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.7087
# Epoch 863/1000
# 34/34 [==============================] - 0s 823us/step - loss: 30.7043
# Epoch 864/1000
# 34/34 [==============================] - 0s 787us/step - loss: 30.7024
# Epoch 865/1000
# 34/34 [==============================] - 0s 943us/step - loss: 30.7055
# Epoch 866/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6911
# Epoch 867/1000
# 34/34 [==============================] - 0s 793us/step - loss: 30.6873
# Epoch 868/1000
# 34/34 [==============================] - 0s 762us/step - loss: 30.6825
# Epoch 869/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6766
# Epoch 870/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6692
# Epoch 871/1000
# 34/34 [==============================] - 0s 981us/step - loss: 30.6734
# Epoch 872/1000
# 34/34 [==============================] - 0s 807us/step - loss: 30.6708
# Epoch 873/1000
# 34/34 [==============================] - 0s 750us/step - loss: 30.6715
# Epoch 874/1000
# 34/34 [==============================] - 0s 955us/step - loss: 30.6726
# Epoch 875/1000
# 34/34 [==============================] - 0s 778us/step - loss: 30.6462
# Epoch 876/1000
# 34/34 [==============================] - 0s 764us/step - loss: 30.6469
# Epoch 877/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6437
# Epoch 878/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6428
# Epoch 879/1000
# 34/34 [==============================] - 0s 869us/step - loss: 30.6413
# Epoch 880/1000
# 34/34 [==============================] - 0s 761us/step - loss: 30.6257
# Epoch 881/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6268
# Epoch 882/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6181
# Epoch 883/1000
# 34/34 [==============================] - 0s 912us/step - loss: 30.6152
# Epoch 884/1000
# 34/34 [==============================] - 0s 780us/step - loss: 30.6180
# Epoch 885/1000
# 34/34 [==============================] - 0s 735us/step - loss: 30.6040
# Epoch 886/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.6028
# Epoch 887/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5939
# Epoch 888/1000
# 34/34 [==============================] - 0s 894us/step - loss: 30.5909
# Epoch 889/1000
# 34/34 [==============================] - 0s 860us/step - loss: 30.5826
# Epoch 890/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5816
# Epoch 891/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5986
# Epoch 892/1000
# 34/34 [==============================] - 0s 908us/step - loss: 30.5764
# Epoch 893/1000
# 34/34 [==============================] - 0s 784us/step - loss: 30.5663
# Epoch 894/1000
# 34/34 [==============================] - 0s 746us/step - loss: 30.5619
# Epoch 895/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5744
# Epoch 896/1000
# 34/34 [==============================] - 0s 984us/step - loss: 30.5724
# Epoch 897/1000
# 34/34 [==============================] - 0s 841us/step - loss: 30.5564
# Epoch 898/1000
# 34/34 [==============================] - 0s 786us/step - loss: 30.5506
# Epoch 899/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5399
# Epoch 900/1000
# 34/34 [==============================] - 0s 908us/step - loss: 30.5410
# Epoch 901/1000
# 34/34 [==============================] - 0s 745us/step - loss: 30.5429
# Epoch 902/1000
# 34/34 [==============================] - 0s 806us/step - loss: 30.5353
# Epoch 903/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5233
# Epoch 904/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5347
# Epoch 905/1000
# 34/34 [==============================] - 0s 791us/step - loss: 30.5178
# Epoch 906/1000
# 34/34 [==============================] - 0s 845us/step - loss: 30.5195
# Epoch 907/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5024
# Epoch 908/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.5116
# Epoch 909/1000
# 34/34 [==============================] - 0s 960us/step - loss: 30.5071
# Epoch 910/1000
# 34/34 [==============================] - 0s 799us/step - loss: 30.4993
# Epoch 911/1000
# 34/34 [==============================] - 0s 794us/step - loss: 30.4864
# Epoch 912/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4837
# Epoch 913/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4779
# Epoch 914/1000
# 34/34 [==============================] - 0s 812us/step - loss: 30.4741
# Epoch 915/1000
# 34/34 [==============================] - 0s 770us/step - loss: 30.4778
# Epoch 916/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4685
# Epoch 917/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4639
# Epoch 918/1000
# 34/34 [==============================] - 0s 860us/step - loss: 30.4614
# Epoch 919/1000
# 34/34 [==============================] - 0s 786us/step - loss: 30.4565
# Epoch 920/1000
# 34/34 [==============================] - 0s 767us/step - loss: 30.4534
# Epoch 921/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4435
# Epoch 922/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4385
# Epoch 923/1000
# 34/34 [==============================] - 0s 768us/step - loss: 30.4570
# Epoch 924/1000
# 34/34 [==============================] - 0s 746us/step - loss: 30.4259
# Epoch 925/1000
# 34/34 [==============================] - 0s 906us/step - loss: 30.4232
# Epoch 926/1000
# 34/34 [==============================] - 0s 998us/step - loss: 30.4273
# Epoch 927/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4212
# Epoch 928/1000
# 34/34 [==============================] - 0s 765us/step - loss: 30.4169
# Epoch 929/1000
# 34/34 [==============================] - 0s 832us/step - loss: 30.4084
# Epoch 930/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4081
# Epoch 931/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4006
# Epoch 932/1000
# 34/34 [==============================] - 0s 817us/step - loss: 30.3935
# Epoch 933/1000
# 34/34 [==============================] - 0s 775us/step - loss: 30.4009
# Epoch 934/1000
# 34/34 [==============================] - 0s 758us/step - loss: 30.3915
# Epoch 935/1000
# 34/34 [==============================] - 0s 984us/step - loss: 30.3902
# Epoch 936/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.3731
# Epoch 937/1000
# 34/34 [==============================] - 0s 855us/step - loss: 30.3725
# Epoch 938/1000
# 34/34 [==============================] - 0s 816us/step - loss: 30.3730
# Epoch 939/1000
# 34/34 [==============================] - 0s 797us/step - loss: 30.3609
# Epoch 940/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.3597
# Epoch 941/1000
# 34/34 [==============================] - 0s 944us/step - loss: 30.3515
# Epoch 942/1000
# 34/34 [==============================] - 0s 879us/step - loss: 30.3616
# Epoch 943/1000
# 34/34 [==============================] - 0s 797us/step - loss: 30.3601
# Epoch 944/1000
# 34/34 [==============================] - 0s 824us/step - loss: 30.3473
# Epoch 945/1000
# 34/34 [==============================] - 0s 762us/step - loss: 30.3354
# Epoch 946/1000
# 34/34 [==============================] - 0s 839us/step - loss: 30.3297
# Epoch 947/1000
# 34/34 [==============================] - 0s 920us/step - loss: 30.3263
# Epoch 948/1000
# 34/34 [==============================] - 0s 798us/step - loss: 30.3230
# Epoch 949/1000
# 34/34 [==============================] - 0s 854us/step - loss: 30.3270
# Epoch 950/1000
# 34/34 [==============================] - 0s 766us/step - loss: 30.3122
# Epoch 951/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.3180
# Epoch 952/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.3014
# Epoch 953/1000
# 34/34 [==============================] - 0s 823us/step - loss: 30.3227
# Epoch 954/1000
# 34/34 [==============================] - 0s 771us/step - loss: 30.3017
# Epoch 955/1000
# 34/34 [==============================] - 0s 841us/step - loss: 30.2962
# Epoch 956/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2959
# Epoch 957/1000
# 34/34 [==============================] - 0s 943us/step - loss: 30.2900
# Epoch 958/1000
# 34/34 [==============================] - 0s 767us/step - loss: 30.2829
# Epoch 959/1000
# 34/34 [==============================] - 0s 774us/step - loss: 30.2817
# Epoch 960/1000
# 34/34 [==============================] - 0s 2ms/step - loss: 30.2713
# Epoch 961/1000
# 34/34 [==============================] - 0s 962us/step - loss: 30.2787
# Epoch 962/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2639
# Epoch 963/1000
# 34/34 [==============================] - 0s 975us/step - loss: 30.2614
# Epoch 964/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2556
# Epoch 965/1000
# 34/34 [==============================] - 0s 837us/step - loss: 30.2566
# Epoch 966/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2471
# Epoch 967/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2405
# Epoch 968/1000
# 34/34 [==============================] - 0s 944us/step - loss: 30.2370
# Epoch 969/1000
# 34/34 [==============================] - 0s 782us/step - loss: 30.2390
# Epoch 970/1000
# 34/34 [==============================] - 0s 745us/step - loss: 30.2301
# Epoch 971/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2327
# Epoch 972/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2337
# Epoch 973/1000
# 34/34 [==============================] - 0s 843us/step - loss: 30.2249
# Epoch 974/1000
# 34/34 [==============================] - 0s 820us/step - loss: 30.2122
# Epoch 975/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2147
# Epoch 976/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2060
# Epoch 977/1000
# 34/34 [==============================] - 0s 820us/step - loss: 30.2022
# Epoch 978/1000
# 34/34 [==============================] - 0s 816us/step - loss: 30.2032
# Epoch 979/1000
# 34/34 [==============================] - 0s 781us/step - loss: 30.1946
# Epoch 980/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.2063
# Epoch 981/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1912
# Epoch 982/1000
# 34/34 [==============================] - 0s 845us/step - loss: 30.1880
# Epoch 983/1000
# 34/34 [==============================] - 0s 834us/step - loss: 30.1789
# Epoch 984/1000
# 34/34 [==============================] - 0s 801us/step - loss: 30.1830
# Epoch 985/1000
# 34/34 [==============================] - 0s 971us/step - loss: 30.1698
# Epoch 986/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1711
# Epoch 987/1000
# 34/34 [==============================] - 0s 863us/step - loss: 30.1629
# Epoch 988/1000
# 34/34 [==============================] - 0s 792us/step - loss: 30.1586
# Epoch 989/1000
# 34/34 [==============================] - 0s 752us/step - loss: 30.1564
# Epoch 990/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1529
# Epoch 991/1000
# 34/34 [==============================] - 0s 972us/step - loss: 30.1519
# Epoch 992/1000
# 34/34 [==============================] - 0s 807us/step - loss: 30.1393
# Epoch 993/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1370
# Epoch 994/1000
# 34/34 [==============================] - 0s 997us/step - loss: 30.1382
# Epoch 995/1000
# 34/34 [==============================] - 0s 855us/step - loss: 30.1354
# Epoch 996/1000
# 34/34 [==============================] - 0s 889us/step - loss: 30.1245
# Epoch 997/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1279
# Epoch 998/1000
# 34/34 [==============================] - 0s 1ms/step - loss: 30.1128
# Epoch 999/1000
# 34/34 [==============================] - 0s 844us/step - loss: 30.1127
# Epoch 1000/1000
# 34/34 [==============================] - 0s 783us/step - loss: 30.1110

# %% [markdown]
# ## Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this you can use the `compute_metrics` function that you coded in the previous assignment:

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %% [markdown]
# At this point only the model that will perform the forecast is ready but you still need to compute the actual forecast.
#
# For this, run the cell below which uses the `generate_forecast` function to compute the forecast. This function generates the next value given a set of the previous `window_size` points for every point in the validation set.

# %%
def generate_forecast(series=G.SERIES, split_time=G.SPLIT_TIME, window_size=G.WINDOW_SIZE):
    forecast = []
    for time in range(len(series) - window_size):
        forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

    forecast = forecast[split_time-window_size:]
    results = np.array(forecast)[:, 0, 0]
    return results


# Save the forecast
dnn_forecast = generate_forecast()

# Plot it
plt.figure(figsize=(10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, dnn_forecast)

# %% [markdown]
# **Expected Output:**
#
# A series similar to this one:
#
# <div>
# <img src="images/forecast.png" width="500"/>
# </div>

# %%
mse, mae = compute_metrics(series_valid, dnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# mse: 28.91, mae: 3.37 for forecast

# %% [markdown]
# **To pass this assignment your forecast should achieve an MSE of 30 or less.**
#
# - If your forecast didn't achieve this threshold try re-training your model with a different architecture or tweaking the optimizer's parameters.
#
#
# - If your forecast did achieve this threshold run the following cell to save your model in a HDF5 file file which will be used for grading and after doing so, submit your assigment for grading.
#
#
# - This environment includes a dummy `my_model.h5` file which is just a dummy model trained for one epoch. **To replace this file with your actual model you need to run the next cell before submitting for grading.**

# %%
# Save your model in HDF5 format
model.save('my_model.h5')

# %% [markdown]
# **Congratulations on finishing this week's assignment!**
#
# You have successfully implemented a neural network capable of forecasting time series while also learning how to leverage Tensorflow's Dataset class to process time series data!
#
# **Keep it up!**
